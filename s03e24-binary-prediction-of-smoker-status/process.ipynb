# %%
# imports
import pandas as pd

# %%
train = pd.read_csv('data/raw/train.csv')
test = pd.read_csv('data/raw/test.csv')
proc_train =  train.copy()
proc_test = test.copy()
target = proc_train['smoking']
proc_train.drop(['smoking'], axis=1, inplace=True)

# %%
proc_train.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  \
# 0              0.6              1               1       135  ...
# 1              0.7              2               2       146  ...
# 2              0.5              1               1       118  ...
# 3              1.2              1               1       131  ...
# 4              1.0              1               1       121  ...
#
#    triglyceride  HDL  LDL  hemoglobin  Urine protein  serum creatinine  AST  \
# 0           300   40   75        16.5              1               1.0   22
# ...

# %% [markdown]
# # check null values

# %%
def describe(df):
    desc = pd.DataFrame(index=df.columns)
    desc['type'] = df.dtypes
    desc['count'] = df.count()
    desc['null*'] = df.isnull().sum()
    desc['null%'] = desc['null*'] / desc['count'] * 100
    desc['unique*'] = df.nunique()
    desc['unique%'] = desc['unique*'] / desc['count'] * 100
    desc = pd.concat([desc, df.describe().drop(['count']).T], axis=1)
    display(desc)

describe(proc_train)
# Out:
#                         type   count  null*  null%  unique*     unique%  \
# id                     int64  159256      0    0.0   159256  100.000000
# age                    int64  159256      0    0.0       18    0.011303
# height(cm)             int64  159256      0    0.0       14    0.008791
# weight(kg)             int64  159256      0    0.0       28    0.017582
# waist(cm)            float64  159256      0    0.0      531    0.333425
# eyesight(left)       float64  159256      0    0.0       20    0.012558
# eyesight(right)      float64  159256      0    0.0       17    0.010675
# hearing(left)          int64  159256      0    0.0        2    0.001256
# hearing(right)         int64  159256      0    0.0        2    0.001256
# systolic               int64  159256      0    0.0      112    0.070327
# relaxation             int64  159256      0    0.0       75    0.047094
# fasting blood sugar    int64  159256      0    0.0      229    0.143794
# ...

# %%
describe(proc_test)
# Out:
#                         type   count  null*  null%  unique*     unique%  \
# id                     int64  106171      0    0.0   106171  100.000000
# age                    int64  106171      0    0.0       18    0.016954
# height(cm)             int64  106171      0    0.0       16    0.015070
# weight(kg)             int64  106171      0    0.0       26    0.024489
# waist(cm)            float64  106171      0    0.0      508    0.478473
# eyesight(left)       float64  106171      0    0.0       20    0.018838
# eyesight(right)      float64  106171      0    0.0       18    0.016954
# hearing(left)          int64  106171      0    0.0        2    0.001884
# hearing(right)         int64  106171      0    0.0        2    0.001884
# systolic               int64  106171      0    0.0      114    0.107374
# relaxation             int64  106171      0    0.0       78    0.073466
# fasting blood sugar    int64  106171      0    0.0      224    0.210980
# ...

# %% [markdown]
# # convert categorical to numebers
# Not necessary

# %% [markdown]
# # adversarial validation

# %% [markdown]
# # check distributions of features and target

# %% [markdown]
# # check corelation between features themselves and with target
